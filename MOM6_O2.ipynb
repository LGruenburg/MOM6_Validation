# %%
import xarray as xr
import matplotlib.pyplot as plt
# %matploblib inline
# Out:
# UsageError: Line magic function `%matploblib` not found.

# %%
O2 = xr.open_dataset('btm_o2.nwa.full.hcast.daily.regrid.r20230520.199301-201912.nc')

# %%
o2 = O2.sel(lat = slice(30,46), lon = slice(360-80, 360-60))

# %%
plt.imshow(o2.btm_o2[10,:,:])
plt.colorbar()

# %%
plt.imshow(o2.btm_o2.mean('time'))
plt.colorbar()

# %%
plt.imshow(o2.groupby('time.season').mean('time').btm_o2[0,:,:])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 plt.imshow(o2.groupby('time.season').mean('time').btm_o2[0,:,:])
#
# File ~\AppData\Local\anaconda3\envs\mom6_validation_env\Lib\site-packages\xarray\core\_aggregations.py:4289, in DatasetGroupByAggregations.mean(self, dim, skipna, keep_attrs, **kwargs)
#    4279     return self._flox_reduce(
#    4280         func="mean",
#    4281         dim=dim,
#    (...)
#    4286         **kwargs,
#    4287     )
#    4288 else:
# -> 4289     return self.reduce(
#    4290         duck_array_ops.mean,
#    4291         dim=dim,
#    4292         skipna=skipna,
#    4293         numeric_only=True,
#    4294         keep_attrs=keep_attrs,
#    4295         **kwargs,
#    4296     )
#
# ...

# %%
import xarray as xr

# lazy loading of data
ds = xr.open_dataset(
    "http://psl.noaa.gov/thredds/dodsC/Projects/CEFI/regional_mom6/cefi_portal/northwest_atlantic/full_domain/hindcast/daily/regrid/r20230520/btm_o2.nwa.full.hcast.daily.regrid.r20230520.199301-201912.nc",
    chunks={"time":1}
)


# loading a slice to memory
da_load = ds["btm_o2"].isel("time"==1).load()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\envs\mom6_validation_env\Lib\site-packages\xarray\backends\file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~\AppData\Local\anaconda3\envs\mom6_validation_env\Lib\site-packages\xarray\backends\lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# ...
