# %% [markdown]
# # Gulf Strem Index
# Laura Gruenburg
# laura.gruenburg@noaa.gov
# 11/1/2024

# %%
# import necessary packages
import xarray as xr
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pn

# %%
gsi_decadal = xr.open_dataset('nwa12_a1_gsi.nc')

# %%
gsi_decadal.
# Out:
# <xarray.Dataset>
# Dimensions:                        (time: 58, member: 10)
# Coordinates:
#   * time                           (time) datetime64[ns] 1965-01-01 ... 2022-...
# Dimensions without coordinates: member
# Data variables:
#     __xarray_dataarray_variable__  (member, time) float64 ...

# %%
plt.fill_between
plt.plot(gsi_decadal.time, gsi_decadal.__xarray_dataarray_variable__.mean('member'))
